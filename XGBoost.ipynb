# %%
import os
import csv
import pandas as pd
import numpy as np

# %%
dataset_names=[]
X_trains=[]
y_trains=[]
X_tests=[]

path = "C:/Users/User/Desktop/SeniorYearFirstSem/DataScience/Competition1_code/Competition_data"
for folder_name in os.listdir(path):
    print(folder_name)
    dataset_names.append(folder_name)
    X_trains.append(pd.read_csv(f"{path}/{folder_name}/X_train.csv", header=0))
    y_trains.append(pd.read_csv(f"{path}/{folder_name}/y_train.csv", header=0))
    X_tests.append(pd.read_csv(f"{path}/{folder_name}/X_test.csv", header=0))
# Out:
# Dataset_1
# Dataset_10
# Dataset_11
# Dataset_12
# Dataset_13
# Dataset_14
# Dataset_15
# Dataset_16
# Dataset_17
# Dataset_18
# Dataset_19
# Dataset_2
# Dataset_20
# Dataset_21
# Dataset_22
# Dataset_23
# Dataset_24
# Dataset_25
# Dataset_26
# Dataset_27
# Dataset_28
# Dataset_29
# Dataset_3
# Dataset_30
# Dataset_31
# Dataset_32
# Dataset_33
# Dataset_34
# Dataset_35
# Dataset_36
# Dataset_37
# Dataset_38
# Dataset_39
# Dataset_4
# Dataset_40
# Dataset_41
# Dataset_42
# Dataset_43
# Dataset_44
# Dataset_45
# Dataset_46
# Dataset_47
# Dataset_48
# Dataset_49
# Dataset_5
# Dataset_6
# Dataset_7
# Dataset_8
# Dataset_9

# %%
## Train & Test & Split & Build Model
from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# %%
def remove_outlier(df, lower_quantile=0.25, upper_quantile=0.75, iqr_multiplier=1.5):
    """
    去除數值型特徵中的異常值（基於 IQR）。
    """
    numeric_cols = df.select_dtypes(include=['float64', 'int64'])
    for col in numeric_cols.columns:
        Q1 = df[col].quantile(lower_quantile)
        Q3 = df[col].quantile(upper_quantile)
        IQR = Q3 - Q1
        lower_bound = Q1 - iqr_multiplier * IQR
        upper_bound = Q3 + iqr_multiplier * IQR
        df[col] = np.clip(df[col], lower_bound, upper_bound)  # 將異常值剪裁到合理範圍
    return df

from sklearn.feature_selection import VarianceThreshold

def remove_low_variance(df, threshold=0.0001):
    """
    移除方差低於 threshold 的特徵。
    """
    selector = VarianceThreshold(threshold=threshold)
    numeric_data = df.select_dtypes(include=['float64', 'int64'])
    high_variance_data = selector.fit_transform(numeric_data)
    retained_features = numeric_data.columns[selector.get_support()]
    df = df[retained_features]
    return df

from scipy.stats import boxcox

def adjust_skewness(df, skew_threshold=2):
    """
    調整偏態，對偏度高於指定閾值的數值型特徵進行處理。
    """
    numeric_cols = df.select_dtypes(include=['float64', 'int64'])
    for col in numeric_cols.columns:
        skewness = df[col].skew()
        if skewness > skew_threshold:  # 偏態較高
            if (df[col] > 0).all():  # Box-Cox 要求數據為正數
                df[col], _ = boxcox(df[col] + 1e-6)
            else:  # 含有非正數，則使用 log1p
                df[col] = np.log1p(df[col] - df[col].min() + 1e-6)
    return df

def select_important_features(X, y, importance_threshold=0.005, retained_top_fraction=0.8):
    """
    基於特徵重要性選擇相關特徵，支持保留累計重要性占前 retained_top_fraction 的特徵。
    """
    # 確保 X 是 DataFrame 格式
    if isinstance(X, np.ndarray):
        X = pd.DataFrame(X)

    model = XGBClassifier(
        n_estimators=1000,          # 等價於 iterations
        learning_rate=0.05,         # 學習率
        max_depth=5,                # 樹的深度
        reg_lambda=3,               # L2 正則化
        scale_pos_weight=1,         # 用來處理類別不平衡
        objective='binary:logistic',# 二元分類
        eval_metric='auc',          # 監控的評估指標
        random_state=42,            # 隨機種子
    )
    # 訓練模型
    model.fit(X, y)

    # 獲取特徵重要性並排序
    feature_importances = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)

    # 根據 importance_threshold 選擇初步篩選的特徵
    selected_features = feature_importances[feature_importances > importance_threshold].index.tolist()

    # 檢查篩選後的特徵數量
    if len(selected_features) < int(len(feature_importances) * retained_top_fraction):
        # 如果刪除的特徵過多，保留重要性最高的特徵
        num_to_retain = int(len(feature_importances) * retained_top_fraction)
        top_features = feature_importances.nlargest(num_to_retain).index.tolist()
        selected_features = list(set(selected_features + top_features))  # 合併去重
        print(f"Retained top {retained_top_fraction*100:.0f}% of features based on importance.")

    # 選擇重要特徵
    X_selected = X[selected_features]

    print(f"Selected {len(selected_features)} important features out of {X.shape[1]}. "
        f"(retained_top_fraction={retained_top_fraction}, importance_threshold={importance_threshold})")


    return X_selected, selected_features


from imblearn.over_sampling import SMOTE, ADASYN

def handle_class_imbalance(X, y, method='smote'):
    """
    使用 SMOTE 或 ADASYN 處理類別不平衡。
    """
    if method == 'smote':
        sampler = SMOTE(random_state=42)
    elif method == 'adasyn':
        sampler = ADASYN(random_state=42)
    else:
        raise ValueError(f"Unsupported imbalance method: {method}")
    
    X_resampled, y_resampled = sampler.fit_resample(X, y)
    print(f"Class imbalance handled: {dict(pd.Series(y_resampled).value_counts())}")
    return X_resampled, y_resampled

# %%
from sklearn.preprocessing import OneHotEncoder
def preprocess_pipeline(X, y=None, imbalance_method='smote', selected_features=None, encoder=None):
    """
    預處理流水線：分離數值和類別特徵，進行數據清理、特徵選擇以及類別不平衡處理。
    """
    print("Starting preprocessing pipeline...")

    # 分離數值型和類別型特徵
    numeric_features = X.select_dtypes(include=['float64', 'int64'])
    categorical_features = X.select_dtypes(include=['object', 'category'])

    # 測試階段
    if y is None:
        print("Testing stage: Applying pre-selected features and encoder...")

        # 驗證必要參數
        if selected_features is None:
            raise ValueError("Testing stage requires selected_features.")
        if categorical_features.shape[1] > 0 and encoder is None:
            raise ValueError("Testing stage requires encoder when categorical features are present.")

        # 處理類別型特徵（如果存在）
        if categorical_features.shape[1] > 0:
            if encoder is None:
                raise ValueError("Encoder is None during testing stage, but categorical features are present.")
            X_categorical = encoder.transform(categorical_features)
        else:
            X_categorical = np.empty((X.shape[0], 0))  # 空數組

        # 數值型特徵
        X_numeric = numeric_features.values  # 轉換為 NumPy

        # 合併數值型和類別型特徵
        X_combined = np.hstack([X_numeric, X_categorical])

        # 應用選擇的特徵
        if isinstance(selected_features[0], str):  # 如果選擇的特徵是列名
            all_feature_names = list(numeric_features.columns)
            if categorical_features.shape[1] > 0:
                all_feature_names += encoder.get_feature_names_out(categorical_features.columns).tolist()
            feature_indices = [all_feature_names.index(feat) for feat in selected_features]
            X_combined = X_combined[:, feature_indices]
        else:  # 如果選擇的特徵是索引
            X_combined = X_combined[:, selected_features]

        print(f"Testing stage: Final dataset shape after applying selected features: {X_combined.shape}")
        return X_combined, None, selected_features, encoder


    # 訓練階段執行完整預處理
    print("Training stage: Performing full preprocessing...")

    # Step 1: Process numeric features
    X_numeric = numeric_features.copy()
    X_numeric = remove_outlier(X_numeric)
    X_numeric = remove_low_variance(X_numeric)
    X_numeric = adjust_skewness(X_numeric)

    # Step 2: Process categorical features (One-hot encoding)
    if categorical_features.shape[1] > 0:
        encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
        X_categorical = encoder.fit_transform(categorical_features)
        categorical_feature_names = encoder.get_feature_names_out(categorical_features.columns)
    else:
        encoder = None
        X_categorical = np.empty((X_numeric.shape[0], 0))  # 空數組
        categorical_feature_names = []

    # Combine numeric and categorical features
    X_combined = np.hstack([X_numeric, X_categorical])
    all_feature_names = list(X_numeric.columns) + list(categorical_feature_names)

    # 修正特徵名稱長度
    if len(all_feature_names) > X_combined.shape[1]:
        all_feature_names = all_feature_names[:X_combined.shape[1]]

    X_combined = pd.DataFrame(X_combined, columns=all_feature_names)
    print(f"Combined dataset shape: {X_combined.shape}")

    # Step 3: Select important features
    X_combined, selected_features = select_important_features(X_combined, y)
    print(f"Selected features: {selected_features}")

    # Step 4: Handle class imbalance
    X_final, y_final = handle_class_imbalance(X_combined, y, method=imbalance_method)

    # 確保數據格式一致
    if isinstance(X_final, np.ndarray):
        X_final = pd.DataFrame(X_final, columns=selected_features)

    print(f"Final dataset shape: {X_final.shape}")
    print("Preprocessing pipeline completed.")
    return X_final, y_final, selected_features, encoder

# %% [markdown]
# >>> After preprocessing(before modifying the threshold value)

# %%
average_auc = 0
y_predicts = []

for i in range(len(dataset_names)):

    # Get features and labels for the current dataset
    X_sample = X_trains[i]  # Keep as pandas DataFrame
    y_sample = y_trains[i].values.ravel()
    X_test = X_tests[i]  # Test data

    # 確保數據格式一致
    if not isinstance(X_sample, pd.DataFrame):
        X_sample = pd.DataFrame(X_sample)
    if not isinstance(X_test, pd.DataFrame):
        X_test = pd.DataFrame(X_test)
    
    # Data preprocessing, perform feature selection during training
    X_sample, y_sample, selected_features, encoder = preprocess_pipeline(
        X_sample,
        y_sample,
        imbalance_method='smote'
    )

    # Preprocess test data, ensuring synchronization with training phase
    X_test_processed, _, _, _ = preprocess_pipeline(
        X_test,
        selected_features=selected_features,  # Use selected features
        encoder=encoder,  # Use encoder from training phase
    )

    # Convert test data back to DataFrame with feature names
    X_test_processed = pd.DataFrame(X_test_processed, columns=selected_features)
    
    # Train-test split
    X_train, X_val, y_train, y_val = train_test_split(X_sample, y_sample, train_size=0.6, random_state=123)
    
    # Define model
    model = XGBClassifier(
        n_estimators=1000,          # 等價於 iterations
        learning_rate=0.05,         # 學習率
        max_depth=5,                # 樹的深度
        reg_lambda=3,               # L2 正則化
        scale_pos_weight=1,         # 用來處理類別不平衡
        objective='binary:logistic',# 二元分類
        #eval_metric='auc',          # 監控的評估指標
        random_state=42,            # 隨機種子
    )

    model.fit(X_train, y_train)
    
    # Validation set prediction
    y_val_proba = model.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_val_proba)
    average_auc += auc

    print(f"Dataset {dataset_names[i]} Validation AUC: {auc:.4f}")

    # Generate prediction probabilities for the test set
    y_test_proba = model.predict_proba(X_test_processed)[:, 1]
    y_predicts.append(pd.DataFrame(y_test_proba, columns=['y_predict_proba']))

    # Save to the corresponding path
    output_dir = os.path.join(path, dataset_names[i])  # Generate path based on root path and dataset name
    os.makedirs(output_dir, exist_ok=True)
    y_predicts[-1].to_csv(os.path.join(output_dir, "y_predict.csv"), index=False)

# Average AUC across datasetss
average_auc /= len(dataset_names)
print(f"Average AUC = {average_auc:.4f}")
# Out:
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (444, 17)
# Retained top 80% of features based on importance.
# Selected 13 important features out of 17. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_17', 'Feature_12', 'Feature_20', 'Feature_11', 'Feature_13', 'Feature_2', 'Feature_1', 'Feature_16', 'Feature_19', 'Feature_3', 'Feature_4', 'Feature_7', 'Feature_5']
# Class imbalance handled: {0: np.int64(313), 1: np.int64(313)}
# Final dataset shape: (626, 13)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (296, 13)
# Dataset Dataset_1 Validation AUC: 0.9103
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (467, 9)
# Selected 9 important features out of 9. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_10', 'Feature_5', 'Feature_7', 'Feature_4', 'Feature_8', 'Feature_6', 'Feature_2', 'Feature_3', 'Feature_1']
# Class imbalance handled: {0: np.int64(273), 1: np.int64(273)}
# Final dataset shape: (546, 9)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (312, 9)
# Dataset Dataset_10 Validation AUC: 0.7898
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (58, 60)
# Retained top 80% of features based on importance.
# Selected 48 important features out of 60. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_46', 'Feature_20', 'Feature_13', 'Feature_6', 'Feature_32', 'Feature_49', 'Feature_1', 'Feature_19', 'Feature_31', 'Feature_4', 'Feature_41', 'Feature_47', 'Feature_17', 'Feature_51', 'Feature_48', 'Feature_50', 'Feature_25', 'Feature_23', 'Feature_52', 'Feature_42', 'Feature_33', 'Feature_3', 'Feature_26', 'Feature_60', 'Feature_38', 'Feature_15', 'Feature_5', 'Feature_57', 'Feature_18', 'Feature_61', 'Feature_22', 'Feature_34', 'Feature_24', 'Feature_27', 'Feature_35', 'Feature_36', 'Feature_10', 'Feature_43', 'Feature_14', 'Feature_30', 'Feature_62', 'Feature_40', 'Feature_37', 'Feature_55', 'Feature_58', 'Feature_21', 'Feature_39', 'Feature_56']
# Class imbalance handled: {0: np.int64(47), 1: np.int64(47)}
# Final dataset shape: (94, 48)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (39, 48)
# Dataset Dataset_11 Validation AUC: 0.9003
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (154, 5)
# Retained top 80% of features based on importance.
# Selected 4 important features out of 5. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_4', 'Feature_1', 'Feature_2', 'Feature_5']
# Class imbalance handled: {0: np.int64(111), 1: np.int64(111)}
# Final dataset shape: (222, 4)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (104, 4)
# Dataset Dataset_12 Validation AUC: 0.9781
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (181, 34)
# Retained top 80% of features based on importance.
# Selected 27 important features out of 34. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_20', 'Feature_13', 'Feature_6', 'Feature_32', 'Feature_1', 'Feature_4', 'Feature_17', 'Feature_9', 'Feature_48', 'Feature_8', 'Feature_33', 'Feature_16', 'Feature_3', 'Feature_15', 'Feature_7', 'Feature_5', 'Feature_18', 'Feature_22', 'Feature_11', 'Feature_34', 'Feature_27', 'Feature_35', 'Feature_10', 'Feature_14', 'Feature_12', 'Feature_21', 'Feature_47']
# Class imbalance handled: {0: np.int64(129), 1: np.int64(129)}
# Final dataset shape: (258, 27)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (122, 27)
# Dataset Dataset_13 Validation AUC: 0.9708
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (181, 37)
# Retained top 80% of features based on importance.
# Selected 29 important features out of 37. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_20', 'Feature_13', 'Feature_6', 'Feature_32', 'Feature_1', 'Feature_19', 'Feature_4', 'Feature_17', 'Feature_9', 'Feature_48', 'Feature_8', 'Feature_33', 'Feature_42', 'Feature_16', 'Feature_3', 'Feature_54', 'Feature_15', 'Feature_7', 'Feature_5', 'Feature_57', 'Feature_22', 'Feature_18', 'Feature_27', 'Feature_10', 'Feature_12', 'Feature_2', 'Feature_55', 'Feature_47', 'Feature_56']
# Class imbalance handled: {0: np.int64(129), 1: np.int64(129)}
# Final dataset shape: (258, 29)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (122, 29)
# Dataset Dataset_14 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (368, 6)
# Selected 6 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_11', 'Feature_2', 'Feature_3', 'Feature_1', 'Feature_8', 'Feature_7']
# Class imbalance handled: {0: np.int64(250), 1: np.int64(250)}
# Final dataset shape: (500, 6)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (246, 6)
# Dataset Dataset_15 Validation AUC: 0.6912
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (465, 13)
# Retained top 80% of features based on importance.
# Selected 10 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_12', 'Feature_8', 'Feature_20', 'Feature_24', 'Feature_2', 'Feature_6', 'Feature_1', 'Feature_19', 'Feature_7', 'Feature_5']
# Class imbalance handled: {1: np.int64(287), 0: np.int64(287)}
# Final dataset shape: (574, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (311, 10)
# Dataset Dataset_16 Validation AUC: 0.9989
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (120, 19)
# Retained top 80% of features based on importance.
# Selected 15 important features out of 19. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_12', 'Feature_8', 'Feature_11', 'Feature_13', 'Feature_14', 'Feature_2', 'Feature_6', 'Feature_24', 'Feature_1', 'Feature_3', 'Feature_19', 'Feature_10', 'Feature_15', 'Feature_5']
# Class imbalance handled: {1.0: np.int64(63), 0.0: np.int64(63)}
# Final dataset shape: (126, 15)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (81, 15)
# Dataset Dataset_17 Validation AUC: 0.9107
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (340, 10)
# Selected 8 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_4', 'Feature_14', 'Feature_2', 'Feature_7', 'Feature_10', 'Feature_12', 'Feature_8', 'Feature_1']
# Class imbalance handled: {0.0: np.int64(321), 1.0: np.int64(321)}
# Final dataset shape: (642, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (227, 8)
# Dataset Dataset_18 Validation AUC: 0.9796
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (341, 25)
# Retained top 80% of features based on importance.
# Selected 20 important features out of 25. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_13', 'Feature_1', 'Feature_4', 'Feature_17', 'Feature_8', 'Feature_23', 'Feature_25', 'Feature_29', 'Feature_3', 'Feature_16', 'Feature_26', 'Feature_5', 'Feature_22', 'Feature_28', 'Feature_24', 'Feature_27', 'Feature_14', 'Feature_30', 'Feature_2', 'Feature_21']
# Class imbalance handled: {0: np.int64(208), 1: np.int64(208)}
# Final dataset shape: (416, 20)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (228, 20)
# Dataset Dataset_19 Validation AUC: 0.9942
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (465, 13)
# Retained top 80% of features based on importance.
# Selected 10 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_12', 'Feature_8', 'Feature_20', 'Feature_24', 'Feature_2', 'Feature_6', 'Feature_1', 'Feature_19', 'Feature_7', 'Feature_5']
# Class imbalance handled: {1: np.int64(287), 0: np.int64(287)}
# Final dataset shape: (574, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (311, 10)
# Dataset Dataset_2 Validation AUC: 0.9989
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (129, 13)
# Retained top 80% of features based on importance.
# Selected 10 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_8', 'Feature_13', 'Feature_2', 'Feature_6', 'Feature_3', 'Feature_1', 'Feature_4', 'Feature_7', 'Feature_5']
# Class imbalance handled: {0: np.int64(91), 1: np.int64(91)}
# Final dataset shape: (182, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (86, 10)
# Dataset Dataset_20 Validation AUC: 0.9674
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (303, 16)
# Retained top 80% of features based on importance.
# Selected 12 important features out of 16. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_12', 'Feature_11', 'Feature_13', 'Feature_2', 'Feature_6', 'Feature_3', 'Feature_1', 'Feature_16', 'Feature_10', 'Feature_4', 'Feature_5']
# Class imbalance handled: {1.0: np.int64(175), 0.0: np.int64(175)}
# Final dataset shape: (350, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (203, 12)
# Dataset Dataset_21 Validation AUC: 0.9800
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (128, 7)
# Selected 7 important features out of 7. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_7', 'Feature_9', 'Feature_6', 'Feature_3', 'Feature_2', 'Feature_5', 'Feature_4']
# Class imbalance handled: {0: np.int64(81), 1: np.int64(81)}
# Final dataset shape: (162, 7)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (86, 7)
# Dataset Dataset_22 Validation AUC: 0.9315
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (354, 14)
# Retained top 80% of features based on importance.
# Selected 11 important features out of 14. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_12', 'Feature_8', 'Feature_11', 'Feature_2', 'Feature_6', 'Feature_1', 'Feature_3', 'Feature_10', 'Feature_4', 'Feature_7', 'Feature_5']
# Class imbalance handled: {1: np.int64(217), 0: np.int64(217)}
# Final dataset shape: (434, 11)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (236, 11)
# Dataset Dataset_23 Validation AUC: 0.9439
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (600, 10)
# Selected 10 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_8', 'Feature_5', 'Feature_6', 'Feature_4', 'Feature_10', 'Feature_3', 'Feature_1', 'Feature_2', 'Feature_11', 'Feature_7']
# Class imbalance handled: {0: np.int64(426), 1: np.int64(426)}
# Final dataset shape: (852, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (400, 10)
# Dataset Dataset_24 Validation AUC: 0.8269
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (135, 6)
# Retained top 80% of features based on importance.
# Selected 4 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_6', 'Feature_3', 'Feature_1', 'Feature_2']
# Class imbalance handled: {0: np.int64(87), 1: np.int64(87)}
# Final dataset shape: (174, 4)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (90, 4)
# Dataset Dataset_25 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (179, 22)
# Retained top 80% of features based on importance.
# Selected 17 important features out of 22. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_17', 'Feature_9', 'Feature_18', 'Feature_22', 'Feature_12', 'Feature_20', 'Feature_25', 'Feature_24', 'Feature_2', 'Feature_6', 'Feature_3', 'Feature_16', 'Feature_26', 'Feature_4', 'Feature_15', 'Feature_7', 'Feature_14']
# Class imbalance handled: {0: np.int64(114), 1: np.int64(114)}
# Final dataset shape: (228, 17)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (120, 17)
# Dataset Dataset_26 Validation AUC: 0.9345
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (206, 6)
# Retained top 80% of features based on importance.
# Selected 4 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_3', 'Feature_1', 'Feature_4', 'Feature_2']
# Class imbalance handled: {0: np.int64(114), 1: np.int64(114)}
# Final dataset shape: (228, 4)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (138, 4)
# Dataset Dataset_27 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (460, 8)
# Selected 8 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_2', 'Feature_5', 'Feature_6', 'Feature_8', 'Feature_4', 'Feature_3', 'Feature_7', 'Feature_1']
# Class imbalance handled: {1: np.int64(299), 0: np.int64(299)}
# Final dataset shape: (598, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (308, 8)
# Dataset Dataset_28 Validation AUC: 0.8932
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (306, 11)
# Retained top 80% of features based on importance.
# Selected 8 important features out of 11. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_11', 'Feature_8', 'Feature_6', 'Feature_3', 'Feature_1', 'Feature_7', 'Feature_5']
# Class imbalance handled: {0.0: np.int64(175), 1.0: np.int64(175)}
# Final dataset shape: (350, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (205, 8)
# Dataset Dataset_29 Validation AUC: 0.9657
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (69, 9)
# Retained top 80% of features based on importance.
# Selected 7 important features out of 9. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_8', 'Feature_2', 'Feature_3', 'Feature_1', 'Feature_4', 'Feature_7', 'Feature_5']
# Class imbalance handled: {0: np.int64(35), 1: np.int64(35)}
# Final dataset shape: (70, 7)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (47, 7)
# Dataset Dataset_3 Validation AUC: 0.8418
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (553, 17)
# Retained top 80% of features based on importance.
# Selected 13 important features out of 17. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_11', 'Feature_8', 'Feature_2', 'Feature_6', 'Feature_27', 'Feature_3', 'Feature_1', 'Feature_26', 'Feature_10', 'Feature_4', 'Feature_7', 'Feature_5']
# Class imbalance handled: {1: np.int64(355), 0: np.int64(355)}
# Final dataset shape: (710, 13)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (370, 13)
# Dataset Dataset_30 Validation AUC: 0.8535
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (81, 13)
# Retained top 80% of features based on importance.
# Selected 10 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_11', 'Feature_8', 'Feature_5', 'Feature_6', 'Feature_1', 'Feature_10', 'Feature_4', 'Feature_15', 'Feature_14']
# Class imbalance handled: {0: np.int64(59), 1: np.int64(59)}
# Final dataset shape: (118, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (54, 10)
# Dataset Dataset_31 Validation AUC: 0.9388
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (593, 3)
# Selected 3 important features out of 3. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_3', 'Feature_1', 'Feature_2']
# Class imbalance handled: {1: np.int64(506), 0: np.int64(506)}
# Final dataset shape: (1012, 3)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (396, 3)
# Dataset Dataset_32 Validation AUC: 0.8808
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (240, 10)
# Retained top 80% of features based on importance.
# Selected 8 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_11', 'Feature_8', 'Feature_2', 'Feature_6', 'Feature_3', 'Feature_4', 'Feature_5']
# Class imbalance handled: {0: np.int64(152), 1: np.int64(152)}
# Final dataset shape: (304, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (160, 8)
# Dataset Dataset_33 Validation AUC: 0.9767
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (274, 11)
# Retained top 80% of features based on importance.
# Selected 8 important features out of 11. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_11', 'Feature_2', 'Feature_3', 'Feature_1', 'Feature_10', 'Feature_7', 'Feature_5']
# Class imbalance handled: {1.0: np.int64(157), 0.0: np.int64(157)}
# Final dataset shape: (314, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (183, 8)
# Dataset Dataset_34 Validation AUC: 0.8468
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (460, 8)
# Selected 8 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_2', 'Feature_6', 'Feature_8', 'Feature_3', 'Feature_7', 'Feature_4', 'Feature_1', 'Feature_5']
# Class imbalance handled: {1: np.int64(299), 0: np.int64(299)}
# Final dataset shape: (598, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (308, 8)
# Dataset Dataset_35 Validation AUC: 0.8700
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (168, 44)
# Retained top 80% of features based on importance.
# Selected 35 important features out of 44. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_53', 'Feature_92', 'Feature_32', 'Feature_1', 'Feature_4', 'Feature_41', 'Feature_31', 'Feature_87', 'Feature_17', 'Feature_9', 'Feature_67', 'Feature_50', 'Feature_8', 'Feature_29', 'Feature_52', 'Feature_42', 'Feature_3', 'Feature_16', 'Feature_26', 'Feature_7', 'Feature_5', 'Feature_18', 'Feature_22', 'Feature_84', 'Feature_11', 'Feature_28', 'Feature_44', 'Feature_24', 'Feature_27', 'Feature_43', 'Feature_14', 'Feature_30', 'Feature_12', 'Feature_2', 'Feature_21']
# Class imbalance handled: {0: np.int64(108), 1: np.int64(108)}
# Final dataset shape: (216, 35)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (113, 35)
# Dataset Dataset_36 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (177, 12)
# Retained top 80% of features based on importance.
# Selected 9 important features out of 12. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_12', 'Feature_8', 'Feature_13', 'Feature_2', 'Feature_6', 'Feature_1', 'Feature_7', 'Feature_5']
# Class imbalance handled: {1: np.int64(95), 0: np.int64(95)}
# Final dataset shape: (190, 9)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (119, 9)
# Dataset Dataset_37 Validation AUC: 0.8987
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (349, 10)
# Selected 10 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_2', 'Feature_5', 'Feature_3', 'Feature_6', 'Feature_1', 'Feature_4', 'Feature_8', 'Feature_7', 'Feature_9', 'Feature_11']
# Class imbalance handled: {1: np.int64(249), 0: np.int64(249)}
# Final dataset shape: (498, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (234, 10)
# Dataset Dataset_38 Validation AUC: 0.8588
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (600, 17)
# Retained top 80% of features based on importance.
# Selected 13 important features out of 17. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_18', 'Feature_9', 'Feature_11', 'Feature_8', 'Feature_13', 'Feature_2', 'Feature_6', 'Feature_1', 'Feature_10', 'Feature_4', 'Feature_15', 'Feature_7', 'Feature_14']
# Class imbalance handled: {0: np.int64(353), 1: np.int64(353)}
# Final dataset shape: (706, 13)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (400, 13)
# Dataset Dataset_39 Validation AUC: 0.9994
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (514, 6)
# Selected 6 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_3', 'Feature_4', 'Feature_2', 'Feature_9', 'Feature_1', 'Feature_8']
# Class imbalance handled: {0: np.int64(486), 1: np.int64(486)}
# Final dataset shape: (972, 6)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (344, 6)
# Dataset Dataset_4 Validation AUC: 0.9814
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (460, 8)
# Selected 8 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_2', 'Feature_6', 'Feature_8', 'Feature_3', 'Feature_7', 'Feature_4', 'Feature_1', 'Feature_5']
# Class imbalance handled: {1: np.int64(299), 0: np.int64(299)}
# Final dataset shape: (598, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (308, 8)
# Dataset Dataset_40 Validation AUC: 0.8700
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (480, 10)
# Retained top 80% of features based on importance.
# Selected 8 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_8', 'Feature_6', 'Feature_3', 'Feature_10', 'Feature_4', 'Feature_7', 'Feature_5']
# Class imbalance handled: {0: np.int64(432), 1: np.int64(432)}
# Final dataset shape: (864, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (321, 8)
# Dataset Dataset_41 Validation AUC: 0.9976
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (120, 6)
# Retained top 80% of features based on importance.
# Selected 4 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_6', 'Feature_4', 'Feature_1', 'Feature_2']
# Class imbalance handled: {0: np.int64(62), 1: np.int64(62)}
# Final dataset shape: (124, 4)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (80, 4)
# Dataset Dataset_42 Validation AUC: 0.9310
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (593, 3)
# Selected 3 important features out of 3. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_3', 'Feature_1', 'Feature_2']
# Class imbalance handled: {1: np.int64(506), 0: np.int64(506)}
# Final dataset shape: (1012, 3)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (396, 3)
# Dataset Dataset_43 Validation AUC: 0.8808
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (60, 4)
# Retained top 80% of features based on importance.
# Selected 3 important features out of 4. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_3', 'Feature_1', 'Feature_2']
# Class imbalance handled: {1: np.int64(43), 0: np.int64(43)}
# Final dataset shape: (86, 3)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (40, 3)
# Dataset Dataset_44 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (158, 4)
# Retained top 80% of features based on importance.
# Selected 3 important features out of 4. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_4', 'Feature_3', 'Feature_2']
# Class imbalance handled: {1: np.int64(147), 0: np.int64(147)}
# Final dataset shape: (294, 3)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (106, 3)
# Dataset Dataset_45 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (176, 8)
# Retained top 80% of features based on importance.
# Selected 6 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_8', 'Feature_13', 'Feature_6', 'Feature_1', 'Feature_7']
# Class imbalance handled: {0.0: np.int64(107), 1.0: np.int64(107)}
# Final dataset shape: (214, 6)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (118, 6)
# Dataset Dataset_46 Validation AUC: 0.8383
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (86, 75)
# Retained top 80% of features based on importance.
# Selected 60 important features out of 75. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_46', 'Feature_74', 'Feature_20', 'Feature_13', 'Feature_59', 'Feature_49', 'Feature_32', 'Feature_6', 'Feature_1', 'Feature_19', 'Feature_4', 'Feature_31', 'Feature_17', 'Feature_9', 'Feature_51', 'Feature_67', 'Feature_48', 'Feature_50', 'Feature_8', 'Feature_25', 'Feature_52', 'Feature_33', 'Feature_42', 'Feature_3', 'Feature_70', 'Feature_26', 'Feature_38', 'Feature_60', 'Feature_54', 'Feature_15', 'Feature_7', 'Feature_5', 'Feature_57', 'Feature_22', 'Feature_61', 'Feature_11', 'Feature_28', 'Feature_44', 'Feature_27', 'Feature_35', 'Feature_36', 'Feature_10', 'Feature_64', 'Feature_69', 'Feature_43', 'Feature_71', 'Feature_14', 'Feature_63', 'Feature_66', 'Feature_30', 'Feature_12', 'Feature_65', 'Feature_2', 'Feature_73', 'Feature_40', 'Feature_37', 'Feature_55', 'Feature_21', 'Feature_47', 'Feature_56']
# Class imbalance handled: {0: np.int64(59), 1: np.int64(59)}
# Final dataset shape: (118, 60)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (58, 60)
# Dataset Dataset_47 Validation AUC: 0.9393
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (237, 21)
# Retained top 80% of features based on importance.
# Selected 16 important features out of 21. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_17', 'Feature_9', 'Feature_18', 'Feature_11', 'Feature_12', 'Feature_13', 'Feature_23', 'Feature_24', 'Feature_2', 'Feature_6', 'Feature_1', 'Feature_3', 'Feature_19', 'Feature_4', 'Feature_7', 'Feature_14']
# Class imbalance handled: {0: np.int64(150), 1: np.int64(150)}
# Final dataset shape: (300, 16)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (158, 16)
# Dataset Dataset_48 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (575, 38)
# Retained top 80% of features based on importance.
# Selected 30 important features out of 38. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_20', 'Feature_6', 'Feature_32', 'Feature_1', 'Feature_19', 'Feature_41', 'Feature_17', 'Feature_8', 'Feature_25', 'Feature_42', 'Feature_3', 'Feature_16', 'Feature_26', 'Feature_15', 'Feature_7', 'Feature_5', 'Feature_22', 'Feature_11', 'Feature_28', 'Feature_34', 'Feature_27', 'Feature_35', 'Feature_36', 'Feature_10', 'Feature_14', 'Feature_12', 'Feature_2', 'Feature_37', 'Feature_21', 'Feature_39']
# Class imbalance handled: {0: np.int64(368), 1: np.int64(368)}
# Final dataset shape: (736, 30)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (384, 30)
# Dataset Dataset_49 Validation AUC: 0.9895
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (324, 19)
# Retained top 80% of features based on importance.
# Selected 15 important features out of 19. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_17', 'Feature_9', 'Feature_11', 'Feature_12', 'Feature_13', 'Feature_14', 'Feature_2', 'Feature_6', 'Feature_3', 'Feature_1', 'Feature_19', 'Feature_16', 'Feature_15', 'Feature_7', 'Feature_5']
# Class imbalance handled: {0: np.int64(303), 1: np.int64(303)}
# Final dataset shape: (606, 15)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (216, 15)
# Dataset Dataset_5 Validation AUC: 0.9940
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (312, 14)
# Retained top 80% of features based on importance.
# Selected 11 important features out of 14. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_12', 'Feature_11', 'Feature_14', 'Feature_2', 'Feature_6', 'Feature_3', 'Feature_1', 'Feature_10', 'Feature_4', 'Feature_15', 'Feature_5']
# Class imbalance handled: {1: np.int64(188), 0: np.int64(188)}
# Final dataset shape: (376, 11)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (208, 11)
# Dataset Dataset_6 Validation AUC: 0.9899
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (369, 12)
# Retained top 80% of features based on importance.
# Selected 9 important features out of 12. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_9', 'Feature_8', 'Feature_2', 'Feature_6', 'Feature_3', 'Feature_10', 'Feature_4', 'Feature_7', 'Feature_5']
# Class imbalance handled: {1: np.int64(321), 0: np.int64(321)}
# Final dataset shape: (642, 9)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (246, 9)
# Dataset Dataset_7 Validation AUC: 0.9996
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (179, 12)
# Selected 9 important features out of 12. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_7', 'Feature_5', 'Feature_12', 'Feature_6', 'Feature_3', 'Feature_11', 'Feature_2', 'Feature_4', 'Feature_1']
# Class imbalance handled: {0: np.int64(121), 1: np.int64(121)}
# Final dataset shape: (242, 9)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (120, 9)
# Dataset Dataset_8 Validation AUC: 0.9651
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (144, 42)
# Retained top 80% of features based on importance.
# Selected 33 important features out of 42. (retained_top_fraction=0.8, importance_threshold=0.05)
# Selected features: ['Feature_46', 'Feature_20', 'Feature_13', 'Feature_6', 'Feature_32', 'Feature_19', 'Feature_31', 'Feature_17', 'Feature_8', 'Feature_25', 'Feature_29', 'Feature_23', 'Feature_45', 'Feature_33', 'Feature_42', 'Feature_26', 'Feature_15', 'Feature_5', 'Feature_18', 'Feature_22', 'Feature_11', 'Feature_28', 'Feature_34', 'Feature_44', 'Feature_24', 'Feature_36', 'Feature_10', 'Feature_43', 'Feature_14', 'Feature_40', 'Feature_37', 'Feature_21', 'Feature_39']
# Class imbalance handled: {1: np.int64(74), 0: np.int64(74)}
# Final dataset shape: (148, 33)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (96, 33)
# Dataset Dataset_9 Validation AUC: 0.9511
# Average AUC = 0.9359

# %% [markdown]
# >>> After preprocessing(after modifying the threshold value)

# %%
average_auc = 0
y_predicts = []

for i in range(len(dataset_names)):

    # Get features and labels for the current dataset
    X_sample = X_trains[i]  # Keep as pandas DataFrame
    y_sample = y_trains[i].values.ravel()
    X_test = X_tests[i]  # Test data

    # 確保數據格式一致
    if not isinstance(X_sample, pd.DataFrame):
        X_sample = pd.DataFrame(X_sample)
    if not isinstance(X_test, pd.DataFrame):
        X_test = pd.DataFrame(X_test)
    
    # Data preprocessing, perform feature selection during training
    X_sample, y_sample, selected_features, encoder = preprocess_pipeline(
        X_sample,
        y_sample,
        imbalance_method='smote'
    )

    # Preprocess test data, ensuring synchronization with training phase
    X_test_processed, _, _, _ = preprocess_pipeline(
        X_test,
        selected_features=selected_features,  # Use selected features
        encoder=encoder,  # Use encoder from training phase
    )

    # Convert test data back to DataFrame with feature names
    X_test_processed = pd.DataFrame(X_test_processed, columns=selected_features)
    
    # Train-test split
    X_train, X_val, y_train, y_val = train_test_split(X_sample, y_sample, train_size=0.6, random_state=123)
    
    # Define model
    model = XGBClassifier(
        n_estimators=1000,          # 等價於 iterations
        learning_rate=0.05,         # 學習率
        max_depth=5,                # 樹的深度
        reg_lambda=3,               # L2 正則化
        scale_pos_weight=1,         # 用來處理類別不平衡
        objective='binary:logistic',# 二元分類
        #eval_metric='auc',          # 監控的評估指標
        random_state=42,            # 隨機種子
    )

    model.fit(X_train, y_train)
    
    # Validation set prediction
    y_val_proba = model.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_val_proba)
    average_auc += auc

    print(f"Dataset {dataset_names[i]} Validation AUC: {auc:.4f}")

    # Generate prediction probabilities for the test set
    y_test_proba = model.predict_proba(X_test_processed)[:, 1]
    y_predicts.append(pd.DataFrame(y_test_proba, columns=['y_predict_proba']))

    # Save to the corresponding path
    output_dir = os.path.join(path, dataset_names[i])  # Generate path based on root path and dataset name
    os.makedirs(output_dir, exist_ok=True)
    y_predicts[-1].to_csv(os.path.join(output_dir, "y_predict.csv"), index=False)

# Average AUC across datasets
average_auc /= len(dataset_names)
print(f"Average AUC = {average_auc:.4f}")
# Out:
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (444, 17)
# Selected 17 important features out of 17. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_1', 'Feature_20', 'Feature_12', 'Feature_2', 'Feature_7', 'Feature_19', 'Feature_4', 'Feature_17', 'Feature_16', 'Feature_11', 'Feature_5', 'Feature_3', 'Feature_13', 'Feature_6', 'Feature_9', 'Feature_8', 'Feature_10']
# Class imbalance handled: {0: np.int64(313), 1: np.int64(313)}
# Final dataset shape: (626, 17)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (296, 17)
# Dataset Dataset_1 Validation AUC: 0.9191
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (467, 9)
# Selected 9 important features out of 9. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_10', 'Feature_5', 'Feature_7', 'Feature_4', 'Feature_8', 'Feature_6', 'Feature_2', 'Feature_3', 'Feature_1']
# Class imbalance handled: {0: np.int64(273), 1: np.int64(273)}
# Final dataset shape: (546, 9)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (312, 9)
# Dataset Dataset_10 Validation AUC: 0.7898
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (58, 62)
# Retained top 80% of features based on importance.
# Selected 49 important features out of 62. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_31', 'Feature_49', 'Feature_21', 'Feature_57', 'Feature_3', 'Feature_51', 'Feature_41', 'Feature_1', 'Feature_6', 'Feature_40', 'Feature_30', 'Feature_5', 'Feature_52', 'Feature_48', 'Feature_27', 'Feature_56', 'Feature_46', 'Feature_10', 'Feature_4', 'Feature_18', 'Feature_20', 'Feature_55', 'Feature_22', 'Feature_62', 'Feature_47', 'Feature_34', 'Feature_12', 'Feature_36', 'Feature_25', 'Feature_43', 'Feature_26', 'Feature_13', 'Feature_16', 'Feature_38', 'Feature_23', 'Feature_58', 'Feature_39', 'Feature_37', 'Feature_14', 'Feature_24', 'Feature_17', 'Feature_42', 'Feature_32', 'Feature_15', 'Feature_33', 'Feature_61', 'Feature_60', 'Feature_2', 'Feature_53']
# Class imbalance handled: {0: np.int64(47), 1: np.int64(47)}
# Final dataset shape: (94, 49)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (39, 49)
# Dataset Dataset_11 Validation AUC: 0.8560
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (154, 5)
# Selected 5 important features out of 5. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_4', 'Feature_1', 'Feature_2', 'Feature_3']
# Class imbalance handled: {0: np.int64(111), 1: np.int64(111)}
# Final dataset shape: (222, 5)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (104, 5)
# Dataset Dataset_12 Validation AUC: 0.9633
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (181, 34)
# Selected 32 important features out of 34. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_34', 'Feature_27', 'Feature_32', 'Feature_15', 'Feature_35', 'Feature_1', 'Feature_9', 'Feature_20', 'Feature_5', 'Feature_16', 'Feature_33', 'Feature_11', 'Feature_4', 'Feature_7', 'Feature_14', 'Feature_17', 'Feature_22', 'Feature_13', 'Feature_6', 'Feature_12', 'Feature_18', 'Feature_21', 'Feature_47', 'Feature_48', 'Feature_10', 'Feature_8', 'Feature_3', 'Feature_2', 'Feature_31', 'Feature_28', 'Feature_54', 'Feature_19']
# Class imbalance handled: {0: np.int64(129), 1: np.int64(129)}
# Final dataset shape: (258, 32)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (122, 32)
# Dataset Dataset_13 Validation AUC: 0.9716
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (181, 37)
# Retained top 80% of features based on importance.
# Selected 29 important features out of 37. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_57', 'Feature_3', 'Feature_1', 'Feature_6', 'Feature_5', 'Feature_48', 'Feature_27', 'Feature_56', 'Feature_10', 'Feature_4', 'Feature_18', 'Feature_20', 'Feature_55', 'Feature_22', 'Feature_9', 'Feature_47', 'Feature_12', 'Feature_8', 'Feature_7', 'Feature_16', 'Feature_13', 'Feature_15', 'Feature_33', 'Feature_42', 'Feature_17', 'Feature_54', 'Feature_32', 'Feature_19', 'Feature_2']
# Class imbalance handled: {0: np.int64(129), 1: np.int64(129)}
# Final dataset shape: (258, 29)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (122, 29)
# Dataset Dataset_14 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (368, 6)
# Selected 6 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_11', 'Feature_2', 'Feature_3', 'Feature_1', 'Feature_8', 'Feature_7']
# Class imbalance handled: {0: np.int64(250), 1: np.int64(250)}
# Final dataset shape: (500, 6)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (246, 6)
# Dataset Dataset_15 Validation AUC: 0.6912
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (465, 13)
# Retained top 80% of features based on importance.
# Selected 10 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_24', 'Feature_12', 'Feature_20', 'Feature_8', 'Feature_1', 'Feature_19', 'Feature_6', 'Feature_7', 'Feature_2']
# Class imbalance handled: {1: np.int64(287), 0: np.int64(287)}
# Final dataset shape: (574, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (311, 10)
# Dataset Dataset_16 Validation AUC: 0.9989
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (120, 19)
# Selected 17 important features out of 19. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_13', 'Feature_10', 'Feature_15', 'Feature_2', 'Feature_8', 'Feature_1', 'Feature_3', 'Feature_12', 'Feature_6', 'Feature_9', 'Feature_11', 'Feature_14', 'Feature_24', 'Feature_19', 'Feature_4', 'Feature_18']
# Class imbalance handled: {1.0: np.int64(63), 0.0: np.int64(63)}
# Final dataset shape: (126, 17)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (81, 17)
# Dataset Dataset_17 Validation AUC: 0.9138
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (340, 10)
# Selected 10 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_4', 'Feature_14', 'Feature_2', 'Feature_7', 'Feature_10', 'Feature_12', 'Feature_8', 'Feature_1', 'Feature_9', 'Feature_13']
# Class imbalance handled: {0.0: np.int64(321), 1.0: np.int64(321)}
# Final dataset shape: (642, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (227, 10)
# Dataset Dataset_18 Validation AUC: 0.9770
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (341, 28)
# Retained top 80% of features based on importance.
# Selected 22 important features out of 28. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_21', 'Feature_3', 'Feature_1', 'Feature_30', 'Feature_5', 'Feature_27', 'Feature_10', 'Feature_4', 'Feature_22', 'Feature_9', 'Feature_8', 'Feature_25', 'Feature_7', 'Feature_26', 'Feature_16', 'Feature_13', 'Feature_28', 'Feature_24', 'Feature_17', 'Feature_19', 'Feature_2', 'Feature_23']
# Class imbalance handled: {0: np.int64(208), 1: np.int64(208)}
# Final dataset shape: (416, 22)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (228, 22)
# Dataset Dataset_19 Validation AUC: 0.9947
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (465, 13)
# Retained top 80% of features based on importance.
# Selected 10 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_24', 'Feature_12', 'Feature_20', 'Feature_8', 'Feature_1', 'Feature_19', 'Feature_6', 'Feature_7', 'Feature_2']
# Class imbalance handled: {1: np.int64(287), 0: np.int64(287)}
# Final dataset shape: (574, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (311, 10)
# Dataset Dataset_2 Validation AUC: 0.9989
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (129, 13)
# Selected 12 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_3', 'Feature_9', 'Feature_7', 'Feature_6', 'Feature_13', 'Feature_4', 'Feature_1', 'Feature_8', 'Feature_5', 'Feature_12', 'Feature_11']
# Class imbalance handled: {0: np.int64(91), 1: np.int64(91)}
# Final dataset shape: (182, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (86, 12)
# Dataset Dataset_20 Validation AUC: 0.9576
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (303, 17)
# Selected 16 important features out of 17. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_10', 'Feature_3', 'Feature_6', 'Feature_2', 'Feature_4', 'Feature_1', 'Feature_12', 'Feature_9', 'Feature_14', 'Feature_13', 'Feature_17', 'Feature_16', 'Feature_7', 'Feature_11', 'Feature_5', 'Feature_8']
# Class imbalance handled: {1.0: np.int64(175), 0.0: np.int64(175)}
# Final dataset shape: (350, 16)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (203, 16)
# Dataset Dataset_21 Validation AUC: 0.9773
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (128, 7)
# Selected 7 important features out of 7. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_7', 'Feature_9', 'Feature_6', 'Feature_3', 'Feature_2', 'Feature_5', 'Feature_4']
# Class imbalance handled: {0: np.int64(81), 1: np.int64(81)}
# Final dataset shape: (162, 7)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (86, 7)
# Dataset Dataset_22 Validation AUC: 0.9315
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (354, 14)
# Selected 12 important features out of 14. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_12', 'Feature_4', 'Feature_6', 'Feature_5', 'Feature_2', 'Feature_8', 'Feature_11', 'Feature_1', 'Feature_3', 'Feature_10', 'Feature_7', 'Feature_14']
# Class imbalance handled: {1: np.int64(217), 0: np.int64(217)}
# Final dataset shape: (434, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (236, 12)
# Dataset Dataset_23 Validation AUC: 0.9469
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (600, 10)
# Selected 10 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_8', 'Feature_5', 'Feature_6', 'Feature_4', 'Feature_10', 'Feature_3', 'Feature_1', 'Feature_2', 'Feature_11', 'Feature_7']
# Class imbalance handled: {0: np.int64(426), 1: np.int64(426)}
# Final dataset shape: (852, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (400, 10)
# Dataset Dataset_24 Validation AUC: 0.8269
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (135, 6)
# Retained top 80% of features based on importance.
# Selected 4 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_1', 'Feature_6', 'Feature_3', 'Feature_2']
# Class imbalance handled: {0: np.int64(87), 1: np.int64(87)}
# Final dataset shape: (174, 4)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (90, 4)
# Dataset Dataset_25 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (179, 22)
# Selected 21 important features out of 22. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_12', 'Feature_9', 'Feature_6', 'Feature_25', 'Feature_17', 'Feature_18', 'Feature_4', 'Feature_3', 'Feature_20', 'Feature_26', 'Feature_14', 'Feature_22', 'Feature_7', 'Feature_15', 'Feature_24', 'Feature_16', 'Feature_2', 'Feature_1', 'Feature_27', 'Feature_23', 'Feature_21']
# Class imbalance handled: {0: np.int64(114), 1: np.int64(114)}
# Final dataset shape: (228, 21)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (120, 21)
# Dataset Dataset_26 Validation AUC: 0.9053
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (206, 6)
# Selected 5 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_1', 'Feature_3', 'Feature_2', 'Feature_4', 'Feature_6']
# Class imbalance handled: {0: np.int64(114), 1: np.int64(114)}
# Final dataset shape: (228, 5)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (138, 5)
# Dataset Dataset_27 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (460, 8)
# Selected 8 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_5', 'Feature_6', 'Feature_8', 'Feature_4', 'Feature_3', 'Feature_7', 'Feature_1']
# Class imbalance handled: {1: np.int64(299), 0: np.int64(299)}
# Final dataset shape: (598, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (308, 8)
# Dataset Dataset_28 Validation AUC: 0.8932
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (306, 11)
# Selected 11 important features out of 11. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_11', 'Feature_3', 'Feature_6', 'Feature_5', 'Feature_1', 'Feature_8', 'Feature_7', 'Feature_9', 'Feature_4', 'Feature_10', 'Feature_13']
# Class imbalance handled: {0.0: np.int64(175), 1.0: np.int64(175)}
# Final dataset shape: (350, 11)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (205, 11)
# Dataset Dataset_29 Validation AUC: 0.9611
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (69, 9)
# Selected 9 important features out of 9. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_3', 'Feature_2', 'Feature_1', 'Feature_8', 'Feature_4', 'Feature_7', 'Feature_5', 'Feature_9', 'Feature_6']
# Class imbalance handled: {0: np.int64(35), 1: np.int64(35)}
# Final dataset shape: (70, 9)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (47, 9)
# Dataset Dataset_3 Validation AUC: 0.8163
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (553, 17)
# Selected 17 important features out of 17. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_7', 'Feature_11', 'Feature_6', 'Feature_8', 'Feature_3', 'Feature_9', 'Feature_5', 'Feature_2', 'Feature_26', 'Feature_27', 'Feature_10', 'Feature_4', 'Feature_1', 'Feature_30', 'Feature_29', 'Feature_28', 'Feature_12']
# Class imbalance handled: {1: np.int64(355), 0: np.int64(355)}
# Final dataset shape: (710, 17)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (370, 17)
# Dataset Dataset_30 Validation AUC: 0.8500
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (81, 13)
# Selected 12 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_15', 'Feature_1', 'Feature_8', 'Feature_11', 'Feature_14', 'Feature_6', 'Feature_4', 'Feature_5', 'Feature_10', 'Feature_9', 'Feature_2', 'Feature_3']
# Class imbalance handled: {0: np.int64(59), 1: np.int64(59)}
# Final dataset shape: (118, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (54, 12)
# Dataset Dataset_31 Validation AUC: 0.9650
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (593, 3)
# Selected 3 important features out of 3. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_3', 'Feature_1', 'Feature_2']
# Class imbalance handled: {1: np.int64(506), 0: np.int64(506)}
# Final dataset shape: (1012, 3)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (396, 3)
# Dataset Dataset_32 Validation AUC: 0.8808
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (240, 11)
# Retained top 80% of features based on importance.
# Selected 8 important features out of 11. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_7', 'Feature_3', 'Feature_4', 'Feature_6', 'Feature_1', 'Feature_11', 'Feature_9', 'Feature_2']
# Class imbalance handled: {0: np.int64(152), 1: np.int64(152)}
# Final dataset shape: (304, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (160, 8)
# Dataset Dataset_33 Validation AUC: 0.9978
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (274, 11)
# Selected 11 important features out of 11. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_3', 'Feature_5', 'Feature_1', 'Feature_7', 'Feature_10', 'Feature_9', 'Feature_11', 'Feature_6', 'Feature_13', 'Feature_12']
# Class imbalance handled: {1.0: np.int64(157), 0.0: np.int64(157)}
# Final dataset shape: (314, 11)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (183, 11)
# Dataset Dataset_34 Validation AUC: 0.8607
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (460, 8)
# Selected 8 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_6', 'Feature_8', 'Feature_3', 'Feature_7', 'Feature_4', 'Feature_1', 'Feature_5']
# Class imbalance handled: {1: np.int64(299), 0: np.int64(299)}
# Final dataset shape: (598, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (308, 8)
# Dataset Dataset_35 Validation AUC: 0.8700
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (168, 44)
# Retained top 80% of features based on importance.
# Selected 35 important features out of 44. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_31', 'Feature_21', 'Feature_3', 'Feature_41', 'Feature_1', 'Feature_44', 'Feature_30', 'Feature_5', 'Feature_52', 'Feature_27', 'Feature_84', 'Feature_4', 'Feature_18', 'Feature_50', 'Feature_22', 'Feature_29', 'Feature_9', 'Feature_87', 'Feature_92', 'Feature_67', 'Feature_12', 'Feature_8', 'Feature_43', 'Feature_7', 'Feature_26', 'Feature_16', 'Feature_28', 'Feature_14', 'Feature_24', 'Feature_17', 'Feature_42', 'Feature_32', 'Feature_11', 'Feature_2', 'Feature_53']
# Class imbalance handled: {0: np.int64(108), 1: np.int64(108)}
# Final dataset shape: (216, 35)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (113, 35)
# Dataset Dataset_36 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (177, 12)
# Selected 12 important features out of 12. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_9', 'Feature_13', 'Feature_7', 'Feature_6', 'Feature_5', 'Feature_8', 'Feature_1', 'Feature_2', 'Feature_12', 'Feature_3', 'Feature_4', 'Feature_11']
# Class imbalance handled: {1: np.int64(95), 0: np.int64(95)}
# Final dataset shape: (190, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (119, 12)
# Dataset Dataset_37 Validation AUC: 0.8987
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (349, 10)
# Selected 10 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_5', 'Feature_3', 'Feature_6', 'Feature_1', 'Feature_4', 'Feature_8', 'Feature_7', 'Feature_9', 'Feature_11']
# Class imbalance handled: {1: np.int64(249), 0: np.int64(249)}
# Final dataset shape: (498, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (234, 10)
# Dataset Dataset_38 Validation AUC: 0.8588
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (600, 17)
# Selected 16 important features out of 17. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_13', 'Feature_6', 'Feature_14', 'Feature_18', 'Feature_1', 'Feature_9', 'Feature_15', 'Feature_7', 'Feature_4', 'Feature_8', 'Feature_2', 'Feature_10', 'Feature_11', 'Feature_3', 'Feature_12', 'Feature_16']
# Class imbalance handled: {0: np.int64(353), 1: np.int64(353)}
# Final dataset shape: (706, 16)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (400, 16)
# Dataset Dataset_39 Validation AUC: 0.9992
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (514, 6)
# Selected 6 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_3', 'Feature_4', 'Feature_2', 'Feature_9', 'Feature_1', 'Feature_8']
# Class imbalance handled: {0: np.int64(486), 1: np.int64(486)}
# Final dataset shape: (972, 6)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (344, 6)
# Dataset Dataset_4 Validation AUC: 0.9814
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (460, 8)
# Selected 8 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_6', 'Feature_8', 'Feature_3', 'Feature_7', 'Feature_4', 'Feature_1', 'Feature_5']
# Class imbalance handled: {1: np.int64(299), 0: np.int64(299)}
# Final dataset shape: (598, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (308, 8)
# Dataset Dataset_40 Validation AUC: 0.8700
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (480, 10)
# Selected 10 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_4', 'Feature_7', 'Feature_6', 'Feature_8', 'Feature_10', 'Feature_3', 'Feature_9', 'Feature_1', 'Feature_2']
# Class imbalance handled: {0: np.int64(432), 1: np.int64(432)}
# Final dataset shape: (864, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (321, 10)
# Dataset Dataset_41 Validation AUC: 0.9976
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (120, 6)
# Retained top 80% of features based on importance.
# Selected 4 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_4', 'Feature_6', 'Feature_1', 'Feature_2']
# Class imbalance handled: {0: np.int64(62), 1: np.int64(62)}
# Final dataset shape: (124, 4)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (80, 4)
# Dataset Dataset_42 Validation AUC: 0.9310
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (593, 3)
# Selected 3 important features out of 3. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_3', 'Feature_1', 'Feature_2']
# Class imbalance handled: {1: np.int64(506), 0: np.int64(506)}
# Final dataset shape: (1012, 3)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (396, 3)
# Dataset Dataset_43 Validation AUC: 0.8808
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (60, 4)
# Retained top 80% of features based on importance.
# Selected 3 important features out of 4. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_1', 'Feature_3', 'Feature_2']
# Class imbalance handled: {1: np.int64(43), 0: np.int64(43)}
# Final dataset shape: (86, 3)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (40, 3)
# Dataset Dataset_44 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (158, 4)
# Selected 3 important features out of 4. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_3', 'Feature_4']
# Class imbalance handled: {1: np.int64(147), 0: np.int64(147)}
# Final dataset shape: (294, 3)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (106, 3)
# Dataset Dataset_45 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (176, 8)
# Selected 8 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_9', 'Feature_7', 'Feature_13', 'Feature_6', 'Feature_8', 'Feature_1', 'Feature_2', 'Feature_3']
# Class imbalance handled: {0.0: np.int64(107), 1.0: np.int64(107)}
# Final dataset shape: (214, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (118, 8)
# Dataset Dataset_46 Validation AUC: 0.8295
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (86, 75)
# Retained top 80% of features based on importance.
# Selected 60 important features out of 75. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_49', 'Feature_31', 'Feature_21', 'Feature_57', 'Feature_3', 'Feature_51', 'Feature_70', 'Feature_1', 'Feature_6', 'Feature_44', 'Feature_71', 'Feature_64', 'Feature_40', 'Feature_30', 'Feature_74', 'Feature_5', 'Feature_52', 'Feature_48', 'Feature_56', 'Feature_66', 'Feature_27', 'Feature_10', 'Feature_46', 'Feature_4', 'Feature_20', 'Feature_50', 'Feature_55', 'Feature_22', 'Feature_9', 'Feature_47', 'Feature_73', 'Feature_67', 'Feature_12', 'Feature_36', 'Feature_8', 'Feature_25', 'Feature_43', 'Feature_7', 'Feature_35', 'Feature_26', 'Feature_13', 'Feature_38', 'Feature_59', 'Feature_63', 'Feature_28', 'Feature_69', 'Feature_65', 'Feature_15', 'Feature_33', 'Feature_54', 'Feature_17', 'Feature_37', 'Feature_32', 'Feature_14', 'Feature_42', 'Feature_61', 'Feature_19', 'Feature_11', 'Feature_60', 'Feature_2']
# Class imbalance handled: {0: np.int64(59), 1: np.int64(59)}
# Final dataset shape: (118, 60)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (58, 60)
# Dataset Dataset_47 Validation AUC: 0.9446
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (237, 21)
# Retained top 80% of features based on importance.
# Selected 16 important features out of 21. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_11', 'Feature_14', 'Feature_3', 'Feature_17', 'Feature_24', 'Feature_4', 'Feature_12', 'Feature_18', 'Feature_6', 'Feature_1', 'Feature_19', 'Feature_7', 'Feature_9', 'Feature_13', 'Feature_2', 'Feature_23']
# Class imbalance handled: {0: np.int64(150), 1: np.int64(150)}
# Final dataset shape: (300, 16)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (158, 16)
# Dataset Dataset_48 Validation AUC: 1.0000
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (575, 38)
# Retained top 80% of features based on importance.
# Selected 30 important features out of 38. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_21', 'Feature_3', 'Feature_41', 'Feature_6', 'Feature_1', 'Feature_5', 'Feature_27', 'Feature_10', 'Feature_20', 'Feature_22', 'Feature_34', 'Feature_12', 'Feature_36', 'Feature_8', 'Feature_25', 'Feature_35', 'Feature_7', 'Feature_26', 'Feature_16', 'Feature_28', 'Feature_39', 'Feature_14', 'Feature_15', 'Feature_42', 'Feature_17', 'Feature_37', 'Feature_32', 'Feature_19', 'Feature_11', 'Feature_2']
# Class imbalance handled: {0: np.int64(368), 1: np.int64(368)}
# Final dataset shape: (736, 30)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (384, 30)
# Dataset Dataset_49 Validation AUC: 0.9893
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (324, 19)
# Selected 19 important features out of 19. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_3', 'Feature_2', 'Feature_5', 'Feature_19', 'Feature_11', 'Feature_6', 'Feature_13', 'Feature_14', 'Feature_7', 'Feature_9', 'Feature_17', 'Feature_1', 'Feature_16', 'Feature_12', 'Feature_15', 'Feature_18', 'Feature_8', 'Feature_4', 'Feature_10']
# Class imbalance handled: {0: np.int64(303), 1: np.int64(303)}
# Final dataset shape: (606, 19)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (216, 19)
# Dataset Dataset_5 Validation AUC: 0.9913
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (312, 14)
# Selected 14 important features out of 14. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_4', 'Feature_3', 'Feature_15', 'Feature_12', 'Feature_2', 'Feature_6', 'Feature_10', 'Feature_11', 'Feature_5', 'Feature_1', 'Feature_14', 'Feature_13', 'Feature_9', 'Feature_7']
# Class imbalance handled: {1: np.int64(188), 0: np.int64(188)}
# Final dataset shape: (376, 14)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (208, 14)
# Dataset Dataset_6 Validation AUC: 0.9891
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (369, 12)
# Selected 12 important features out of 12. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_4', 'Feature_3', 'Feature_10', 'Feature_8', 'Feature_6', 'Feature_2', 'Feature_9', 'Feature_7', 'Feature_11', 'Feature_12', 'Feature_1']
# Class imbalance handled: {1: np.int64(321), 0: np.int64(321)}
# Final dataset shape: (642, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (246, 12)
# Dataset Dataset_7 Validation AUC: 0.9986
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (179, 12)
# Selected 12 important features out of 12. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_7', 'Feature_5', 'Feature_12', 'Feature_6', 'Feature_3', 'Feature_11', 'Feature_2', 'Feature_4', 'Feature_1', 'Feature_8', 'Feature_9', 'Feature_10']
# Class imbalance handled: {0: np.int64(121), 1: np.int64(121)}
# Final dataset shape: (242, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (120, 12)
# Dataset Dataset_8 Validation AUC: 0.9511
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (144, 43)
# Selected 36 important features out of 43. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_32', 'Feature_13', 'Feature_43', 'Feature_19', 'Feature_29', 'Feature_26', 'Feature_14', 'Feature_10', 'Feature_44', 'Feature_40', 'Feature_22', 'Feature_21', 'Feature_31', 'Feature_33', 'Feature_11', 'Feature_24', 'Feature_6', 'Feature_25', 'Feature_42', 'Feature_45', 'Feature_23', 'Feature_17', 'Feature_37', 'Feature_20', 'Feature_27', 'Feature_28', 'Feature_18', 'Feature_39', 'Feature_8', 'Feature_36', 'Feature_15', 'Feature_46', 'Feature_34', 'Feature_16', 'Feature_5', 'Feature_30']
# Class imbalance handled: {1: np.int64(74), 0: np.int64(74)}
# Final dataset shape: (148, 36)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (96, 36)
# Dataset Dataset_9 Validation AUC: 0.8689
# Average AUC = 0.9325

# %% [markdown]
# >>> Conditional Preprocessing

# %%
average_auc = 0
y_predicts = []

for i in range(len(dataset_names)):

    # 獲取當前數據集的特徵和標籤
    X_sample = X_trains[i]
    y_sample = y_trains[i].values.ravel()
    X_test = X_tests[i]

    # 確保數據格式一致
    if not isinstance(X_sample, pd.DataFrame):
        X_sample = pd.DataFrame(X_sample)
    if not isinstance(X_test, pd.DataFrame):
        X_test = pd.DataFrame(X_test)

    # 定義模型
    model = XGBClassifier(
        n_estimators=1000,          # 等價於 iterations
        learning_rate=0.05,         # 學習率
        max_depth=5,                # 樹的深度
        reg_lambda=3,               # L2 正則化
        scale_pos_weight=1,         # 用來處理類別不平衡
        objective='binary:logistic',# 二元分類
        #eval_metric='auc',          # 監控的評估指標
        random_state=42,            # 隨機種子
    )

    # Step 1: 測試未經預處理的性能
    X_train, X_val, y_train, y_val = train_test_split(X_sample, y_sample, train_size=0.6, random_state=123)
    model.fit(X_train, y_train)
    y_val_proba_raw = model.predict_proba(X_val)[:, 1]
    auc_raw = roc_auc_score(y_val, y_val_proba_raw)

    print(f"Dataset {dataset_names[i]} Raw Validation AUC: {auc_raw:.4f}")

    # 如果未經預處理的 AUC 已經達到 1.0，則跳過預處理
    if auc_raw >= 1.0:
        print(f"Dataset {dataset_names[i]} reached perfect AUC without preprocessing. Skipping preprocessing.")
        X_test_processed = X_test
    else:
        # Step 2: 預處理數據
        X_sample_preprocessed, y_sample_preprocessed, selected_features, encoder = preprocess_pipeline(
            X_sample,
            y_sample,
            imbalance_method='smote'
        )

        # 預處理測試數據
        X_test_processed, _, _, _ = preprocess_pipeline(
            X_test,
            selected_features=selected_features,
            encoder=encoder,
        )

        # 修正測試數據列名，確保與訓練數據一致
        X_test_processed = pd.DataFrame(X_test_processed, columns=X_sample_preprocessed.columns)

        # Step 3: 測試經過預處理的性能
        X_train_preprocessed, X_val_preprocessed, y_train_preprocessed, y_val_preprocessed = train_test_split(
            X_sample_preprocessed, y_sample_preprocessed, train_size=0.6, random_state=123
        )
        model.fit(X_train_preprocessed, y_train_preprocessed)
        y_val_proba_preprocessed = model.predict_proba(X_val_preprocessed)[:, 1]
        auc_preprocessed = roc_auc_score(y_val_preprocessed, y_val_proba_preprocessed)

        print(f"Dataset {dataset_names[i]} Preprocessed Validation AUC: {auc_preprocessed:.4f}")

        # 選擇較高性能的數據集
        if auc_preprocessed > auc_raw:
            print(f"Using preprocessed data for Dataset {dataset_names[i]}.")
            X_sample, y_sample = X_sample_preprocessed, y_sample_preprocessed
        else:
            print(f"Using raw data for Dataset {dataset_names[i]}.")
            X_test_processed = X_test  # 如果原始數據表現更好

    # Step 4: 最終模型訓練和測試
    model.fit(X_sample, y_sample)

    # 修正測試數據列名
    X_test_processed = pd.DataFrame(X_test_processed, columns=X_sample.columns)

    y_test_proba = model.predict_proba(X_test_processed)[:, 1]
    y_predicts.append(pd.DataFrame(y_test_proba, columns=['y_predict_proba']))

    # 保存到對應路徑
    output_dir = os.path.join(path, dataset_names[i])
    os.makedirs(output_dir, exist_ok=True)
    y_predicts[-1].to_csv(os.path.join(output_dir, "y_predict.csv"), index=False)

    # 更新 AUC 統計
    auc_preprocessed = locals().get('auc_preprocessed', -1)
    average_auc += max(auc_raw, auc_preprocessed) if auc_preprocessed != -1 else auc_raw

# Average AUC across datasets
average_auc /= len(dataset_names)
print(f"Average AUC = {average_auc:.4f}")
# Out:
# Dataset Dataset_1 Raw Validation AUC: 0.8389
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (444, 17)
# Selected 17 important features out of 17. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_1', 'Feature_20', 'Feature_12', 'Feature_2', 'Feature_7', 'Feature_19', 'Feature_4', 'Feature_17', 'Feature_16', 'Feature_11', 'Feature_5', 'Feature_3', 'Feature_13', 'Feature_6', 'Feature_9', 'Feature_8', 'Feature_10']
# Class imbalance handled: {0: np.int64(313), 1: np.int64(313)}
# Final dataset shape: (626, 17)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (296, 17)
# Dataset Dataset_1 Preprocessed Validation AUC: 0.9191
# Using preprocessed data for Dataset Dataset_1.
# Dataset Dataset_10 Raw Validation AUC: 0.7510
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (467, 9)
# Selected 9 important features out of 9. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_10', 'Feature_5', 'Feature_7', 'Feature_4', 'Feature_8', 'Feature_6', 'Feature_2', 'Feature_3', 'Feature_1']
# Class imbalance handled: {0: np.int64(273), 1: np.int64(273)}
# Final dataset shape: (546, 9)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (312, 9)
# Dataset Dataset_10 Preprocessed Validation AUC: 0.7898
# Using preprocessed data for Dataset Dataset_10.
# Dataset Dataset_11 Raw Validation AUC: 0.6723
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (58, 62)
# Retained top 80% of features based on importance.
# Selected 49 important features out of 62. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_31', 'Feature_49', 'Feature_21', 'Feature_57', 'Feature_3', 'Feature_51', 'Feature_41', 'Feature_1', 'Feature_6', 'Feature_40', 'Feature_30', 'Feature_5', 'Feature_52', 'Feature_48', 'Feature_27', 'Feature_56', 'Feature_46', 'Feature_10', 'Feature_4', 'Feature_18', 'Feature_20', 'Feature_55', 'Feature_22', 'Feature_62', 'Feature_47', 'Feature_34', 'Feature_12', 'Feature_36', 'Feature_25', 'Feature_43', 'Feature_26', 'Feature_13', 'Feature_16', 'Feature_38', 'Feature_23', 'Feature_58', 'Feature_39', 'Feature_37', 'Feature_14', 'Feature_24', 'Feature_17', 'Feature_42', 'Feature_32', 'Feature_15', 'Feature_33', 'Feature_61', 'Feature_60', 'Feature_2', 'Feature_53']
# Class imbalance handled: {0: np.int64(47), 1: np.int64(47)}
# Final dataset shape: (94, 49)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (39, 49)
# Dataset Dataset_11 Preprocessed Validation AUC: 0.8560
# Using preprocessed data for Dataset Dataset_11.
# Dataset Dataset_12 Raw Validation AUC: 0.9792
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (154, 5)
# Selected 5 important features out of 5. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_4', 'Feature_1', 'Feature_2', 'Feature_3']
# Class imbalance handled: {0: np.int64(111), 1: np.int64(111)}
# Final dataset shape: (222, 5)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (104, 5)
# Dataset Dataset_12 Preprocessed Validation AUC: 0.9633
# Using raw data for Dataset Dataset_12.
# Dataset Dataset_13 Raw Validation AUC: 0.8568
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (181, 34)
# Selected 32 important features out of 34. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_34', 'Feature_27', 'Feature_32', 'Feature_15', 'Feature_35', 'Feature_1', 'Feature_9', 'Feature_20', 'Feature_5', 'Feature_16', 'Feature_33', 'Feature_11', 'Feature_4', 'Feature_7', 'Feature_14', 'Feature_17', 'Feature_22', 'Feature_13', 'Feature_6', 'Feature_12', 'Feature_18', 'Feature_21', 'Feature_47', 'Feature_48', 'Feature_10', 'Feature_8', 'Feature_3', 'Feature_2', 'Feature_31', 'Feature_28', 'Feature_54', 'Feature_19']
# Class imbalance handled: {0: np.int64(129), 1: np.int64(129)}
# Final dataset shape: (258, 32)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (122, 32)
# Dataset Dataset_13 Preprocessed Validation AUC: 0.9716
# Using preprocessed data for Dataset Dataset_13.
# Dataset Dataset_14 Raw Validation AUC: 1.0000
# Dataset Dataset_14 reached perfect AUC without preprocessing. Skipping preprocessing.
# Dataset Dataset_15 Raw Validation AUC: 0.6725
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (368, 6)
# Selected 6 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_11', 'Feature_2', 'Feature_3', 'Feature_1', 'Feature_8', 'Feature_7']
# Class imbalance handled: {0: np.int64(250), 1: np.int64(250)}
# Final dataset shape: (500, 6)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (246, 6)
# Dataset Dataset_15 Preprocessed Validation AUC: 0.6912
# Using preprocessed data for Dataset Dataset_15.
# Dataset Dataset_16 Raw Validation AUC: 0.9984
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (465, 13)
# Retained top 80% of features based on importance.
# Selected 10 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_24', 'Feature_12', 'Feature_20', 'Feature_8', 'Feature_1', 'Feature_19', 'Feature_6', 'Feature_7', 'Feature_2']
# Class imbalance handled: {1: np.int64(287), 0: np.int64(287)}
# Final dataset shape: (574, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (311, 10)
# Dataset Dataset_16 Preprocessed Validation AUC: 0.9989
# Using preprocessed data for Dataset Dataset_16.
# Dataset Dataset_17 Raw Validation AUC: 0.9700
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (120, 19)
# Selected 17 important features out of 19. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_13', 'Feature_10', 'Feature_15', 'Feature_2', 'Feature_8', 'Feature_1', 'Feature_3', 'Feature_12', 'Feature_6', 'Feature_9', 'Feature_11', 'Feature_14', 'Feature_24', 'Feature_19', 'Feature_4', 'Feature_18']
# Class imbalance handled: {1.0: np.int64(63), 0.0: np.int64(63)}
# Final dataset shape: (126, 17)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (81, 17)
# Dataset Dataset_17 Preprocessed Validation AUC: 0.9138
# Using raw data for Dataset Dataset_17.
# Dataset Dataset_18 Raw Validation AUC: 1.0000
# Dataset Dataset_18 reached perfect AUC without preprocessing. Skipping preprocessing.
# Dataset Dataset_19 Raw Validation AUC: 0.9877
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (341, 28)
# Retained top 80% of features based on importance.
# Selected 22 important features out of 28. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_21', 'Feature_3', 'Feature_1', 'Feature_30', 'Feature_5', 'Feature_27', 'Feature_10', 'Feature_4', 'Feature_22', 'Feature_9', 'Feature_8', 'Feature_25', 'Feature_7', 'Feature_26', 'Feature_16', 'Feature_13', 'Feature_28', 'Feature_24', 'Feature_17', 'Feature_19', 'Feature_2', 'Feature_23']
# Class imbalance handled: {0: np.int64(208), 1: np.int64(208)}
# Final dataset shape: (416, 22)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (228, 22)
# Dataset Dataset_19 Preprocessed Validation AUC: 0.9947
# Using preprocessed data for Dataset Dataset_19.
# Dataset Dataset_2 Raw Validation AUC: 0.9984
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (465, 13)
# Retained top 80% of features based on importance.
# Selected 10 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_24', 'Feature_12', 'Feature_20', 'Feature_8', 'Feature_1', 'Feature_19', 'Feature_6', 'Feature_7', 'Feature_2']
# Class imbalance handled: {1: np.int64(287), 0: np.int64(287)}
# Final dataset shape: (574, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (311, 10)
# Dataset Dataset_2 Preprocessed Validation AUC: 0.9989
# Using preprocessed data for Dataset Dataset_2.
# Dataset Dataset_20 Raw Validation AUC: 0.8868
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (129, 13)
# Selected 12 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_3', 'Feature_9', 'Feature_7', 'Feature_6', 'Feature_13', 'Feature_4', 'Feature_1', 'Feature_8', 'Feature_5', 'Feature_12', 'Feature_11']
# Class imbalance handled: {0: np.int64(91), 1: np.int64(91)}
# Final dataset shape: (182, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (86, 12)
# Dataset Dataset_20 Preprocessed Validation AUC: 0.9576
# Using preprocessed data for Dataset Dataset_20.
# Dataset Dataset_21 Raw Validation AUC: 0.9442
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (303, 17)
# Selected 16 important features out of 17. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_10', 'Feature_3', 'Feature_6', 'Feature_2', 'Feature_4', 'Feature_1', 'Feature_12', 'Feature_9', 'Feature_14', 'Feature_13', 'Feature_17', 'Feature_16', 'Feature_7', 'Feature_11', 'Feature_5', 'Feature_8']
# Class imbalance handled: {1.0: np.int64(175), 0.0: np.int64(175)}
# Final dataset shape: (350, 16)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (203, 16)
# Dataset Dataset_21 Preprocessed Validation AUC: 0.9773
# Using preprocessed data for Dataset Dataset_21.
# Dataset Dataset_22 Raw Validation AUC: 0.8750
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (128, 7)
# Selected 7 important features out of 7. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_7', 'Feature_9', 'Feature_6', 'Feature_3', 'Feature_2', 'Feature_5', 'Feature_4']
# Class imbalance handled: {0: np.int64(81), 1: np.int64(81)}
# Final dataset shape: (162, 7)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (86, 7)
# Dataset Dataset_22 Preprocessed Validation AUC: 0.9315
# Using preprocessed data for Dataset Dataset_22.
# Dataset Dataset_23 Raw Validation AUC: 0.9560
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (354, 14)
# Selected 12 important features out of 14. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_12', 'Feature_4', 'Feature_6', 'Feature_5', 'Feature_2', 'Feature_8', 'Feature_11', 'Feature_1', 'Feature_3', 'Feature_10', 'Feature_7', 'Feature_14']
# Class imbalance handled: {1: np.int64(217), 0: np.int64(217)}
# Final dataset shape: (434, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (236, 12)
# Dataset Dataset_23 Preprocessed Validation AUC: 0.9469
# Using raw data for Dataset Dataset_23.
# Dataset Dataset_24 Raw Validation AUC: 0.5899
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (600, 10)
# Selected 10 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_8', 'Feature_5', 'Feature_6', 'Feature_4', 'Feature_10', 'Feature_3', 'Feature_1', 'Feature_2', 'Feature_11', 'Feature_7']
# Class imbalance handled: {0: np.int64(426), 1: np.int64(426)}
# Final dataset shape: (852, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (400, 10)
# Dataset Dataset_24 Preprocessed Validation AUC: 0.8269
# Using preprocessed data for Dataset Dataset_24.
# Dataset Dataset_25 Raw Validation AUC: 1.0000
# Dataset Dataset_25 reached perfect AUC without preprocessing. Skipping preprocessing.
# Dataset Dataset_26 Raw Validation AUC: 0.8473
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (179, 22)
# Selected 21 important features out of 22. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_12', 'Feature_9', 'Feature_6', 'Feature_25', 'Feature_17', 'Feature_18', 'Feature_4', 'Feature_3', 'Feature_20', 'Feature_26', 'Feature_14', 'Feature_22', 'Feature_7', 'Feature_15', 'Feature_24', 'Feature_16', 'Feature_2', 'Feature_1', 'Feature_27', 'Feature_23', 'Feature_21']
# Class imbalance handled: {0: np.int64(114), 1: np.int64(114)}
# Final dataset shape: (228, 21)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (120, 21)
# Dataset Dataset_26 Preprocessed Validation AUC: 0.9053
# Using preprocessed data for Dataset Dataset_26.
# Dataset Dataset_27 Raw Validation AUC: 1.0000
# Dataset Dataset_27 reached perfect AUC without preprocessing. Skipping preprocessing.
# Dataset Dataset_28 Raw Validation AUC: 0.8030
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (460, 8)
# Selected 8 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_5', 'Feature_6', 'Feature_8', 'Feature_4', 'Feature_3', 'Feature_7', 'Feature_1']
# Class imbalance handled: {1: np.int64(299), 0: np.int64(299)}
# Final dataset shape: (598, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (308, 8)
# Dataset Dataset_28 Preprocessed Validation AUC: 0.8932
# Using preprocessed data for Dataset Dataset_28.
# Dataset Dataset_29 Raw Validation AUC: 0.9673
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (306, 11)
# Selected 11 important features out of 11. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_11', 'Feature_3', 'Feature_6', 'Feature_5', 'Feature_1', 'Feature_8', 'Feature_7', 'Feature_9', 'Feature_4', 'Feature_10', 'Feature_13']
# Class imbalance handled: {0.0: np.int64(175), 1.0: np.int64(175)}
# Final dataset shape: (350, 11)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (205, 11)
# Dataset Dataset_29 Preprocessed Validation AUC: 0.9611
# Using raw data for Dataset Dataset_29.
# Dataset Dataset_3 Raw Validation AUC: 0.7908
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (69, 9)
# Selected 9 important features out of 9. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_3', 'Feature_2', 'Feature_1', 'Feature_8', 'Feature_4', 'Feature_7', 'Feature_5', 'Feature_9', 'Feature_6']
# Class imbalance handled: {0: np.int64(35), 1: np.int64(35)}
# Final dataset shape: (70, 9)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (47, 9)
# Dataset Dataset_3 Preprocessed Validation AUC: 0.8163
# Using preprocessed data for Dataset Dataset_3.
# Dataset Dataset_30 Raw Validation AUC: 0.7289
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (553, 17)
# Selected 17 important features out of 17. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_7', 'Feature_11', 'Feature_6', 'Feature_8', 'Feature_3', 'Feature_9', 'Feature_5', 'Feature_2', 'Feature_26', 'Feature_27', 'Feature_10', 'Feature_4', 'Feature_1', 'Feature_30', 'Feature_29', 'Feature_28', 'Feature_12']
# Class imbalance handled: {1: np.int64(355), 0: np.int64(355)}
# Final dataset shape: (710, 17)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (370, 17)
# Dataset Dataset_30 Preprocessed Validation AUC: 0.8500
# Using preprocessed data for Dataset Dataset_30.
# Dataset Dataset_31 Raw Validation AUC: 0.6700
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (81, 13)
# Selected 12 important features out of 13. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_15', 'Feature_1', 'Feature_8', 'Feature_11', 'Feature_14', 'Feature_6', 'Feature_4', 'Feature_5', 'Feature_10', 'Feature_9', 'Feature_2', 'Feature_3']
# Class imbalance handled: {0: np.int64(59), 1: np.int64(59)}
# Final dataset shape: (118, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (54, 12)
# Dataset Dataset_31 Preprocessed Validation AUC: 0.9650
# Using preprocessed data for Dataset Dataset_31.
# Dataset Dataset_32 Raw Validation AUC: 0.6947
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (593, 3)
# Selected 3 important features out of 3. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_3', 'Feature_1', 'Feature_2']
# Class imbalance handled: {1: np.int64(506), 0: np.int64(506)}
# Final dataset shape: (1012, 3)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (396, 3)
# Dataset Dataset_32 Preprocessed Validation AUC: 0.8808
# Using preprocessed data for Dataset Dataset_32.
# Dataset Dataset_33 Raw Validation AUC: 0.9991
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (240, 11)
# Retained top 80% of features based on importance.
# Selected 8 important features out of 11. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_7', 'Feature_3', 'Feature_4', 'Feature_6', 'Feature_1', 'Feature_11', 'Feature_9', 'Feature_2']
# Class imbalance handled: {0: np.int64(152), 1: np.int64(152)}
# Final dataset shape: (304, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (160, 8)
# Dataset Dataset_33 Preprocessed Validation AUC: 0.9978
# Using raw data for Dataset Dataset_33.
# Dataset Dataset_34 Raw Validation AUC: 0.8477
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (274, 11)
# Selected 11 important features out of 11. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_3', 'Feature_5', 'Feature_1', 'Feature_7', 'Feature_10', 'Feature_9', 'Feature_11', 'Feature_6', 'Feature_13', 'Feature_12']
# Class imbalance handled: {1.0: np.int64(157), 0.0: np.int64(157)}
# Final dataset shape: (314, 11)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (183, 11)
# Dataset Dataset_34 Preprocessed Validation AUC: 0.8607
# Using preprocessed data for Dataset Dataset_34.
# Dataset Dataset_35 Raw Validation AUC: 0.8048
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (460, 8)
# Selected 8 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_6', 'Feature_8', 'Feature_3', 'Feature_7', 'Feature_4', 'Feature_1', 'Feature_5']
# Class imbalance handled: {1: np.int64(299), 0: np.int64(299)}
# Final dataset shape: (598, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (308, 8)
# Dataset Dataset_35 Preprocessed Validation AUC: 0.8700
# Using preprocessed data for Dataset Dataset_35.
# Dataset Dataset_36 Raw Validation AUC: 1.0000
# Dataset Dataset_36 reached perfect AUC without preprocessing. Skipping preprocessing.
# Dataset Dataset_37 Raw Validation AUC: 0.8752
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (177, 12)
# Selected 12 important features out of 12. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_9', 'Feature_13', 'Feature_7', 'Feature_6', 'Feature_5', 'Feature_8', 'Feature_1', 'Feature_2', 'Feature_12', 'Feature_3', 'Feature_4', 'Feature_11']
# Class imbalance handled: {1: np.int64(95), 0: np.int64(95)}
# Final dataset shape: (190, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (119, 12)
# Dataset Dataset_37 Preprocessed Validation AUC: 0.8987
# Using preprocessed data for Dataset Dataset_37.
# Dataset Dataset_38 Raw Validation AUC: 0.7454
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (349, 10)
# Selected 10 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_5', 'Feature_3', 'Feature_6', 'Feature_1', 'Feature_4', 'Feature_8', 'Feature_7', 'Feature_9', 'Feature_11']
# Class imbalance handled: {1: np.int64(249), 0: np.int64(249)}
# Final dataset shape: (498, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (234, 10)
# Dataset Dataset_38 Preprocessed Validation AUC: 0.8588
# Using preprocessed data for Dataset Dataset_38.
# Dataset Dataset_39 Raw Validation AUC: 0.9980
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (600, 17)
# Selected 16 important features out of 17. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_13', 'Feature_6', 'Feature_14', 'Feature_18', 'Feature_1', 'Feature_9', 'Feature_15', 'Feature_7', 'Feature_4', 'Feature_8', 'Feature_2', 'Feature_10', 'Feature_11', 'Feature_3', 'Feature_12', 'Feature_16']
# Class imbalance handled: {0: np.int64(353), 1: np.int64(353)}
# Final dataset shape: (706, 16)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (400, 16)
# Dataset Dataset_39 Preprocessed Validation AUC: 0.9992
# Using preprocessed data for Dataset Dataset_39.
# Dataset Dataset_4 Raw Validation AUC: 0.5552
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (514, 6)
# Selected 6 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_3', 'Feature_4', 'Feature_2', 'Feature_9', 'Feature_1', 'Feature_8']
# Class imbalance handled: {0: np.int64(486), 1: np.int64(486)}
# Final dataset shape: (972, 6)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (344, 6)
# Dataset Dataset_4 Preprocessed Validation AUC: 0.9814
# Using preprocessed data for Dataset Dataset_4.
# Dataset Dataset_40 Raw Validation AUC: 0.8048
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (460, 8)
# Selected 8 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_2', 'Feature_6', 'Feature_8', 'Feature_3', 'Feature_7', 'Feature_4', 'Feature_1', 'Feature_5']
# Class imbalance handled: {1: np.int64(299), 0: np.int64(299)}
# Final dataset shape: (598, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (308, 8)
# Dataset Dataset_40 Preprocessed Validation AUC: 0.8700
# Using preprocessed data for Dataset Dataset_40.
# Dataset Dataset_41 Raw Validation AUC: 0.9837
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (480, 10)
# Selected 10 important features out of 10. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_4', 'Feature_7', 'Feature_6', 'Feature_8', 'Feature_10', 'Feature_3', 'Feature_9', 'Feature_1', 'Feature_2']
# Class imbalance handled: {0: np.int64(432), 1: np.int64(432)}
# Final dataset shape: (864, 10)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (321, 10)
# Dataset Dataset_41 Preprocessed Validation AUC: 0.9976
# Using preprocessed data for Dataset Dataset_41.
# Dataset Dataset_42 Raw Validation AUC: 0.9310
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (120, 6)
# Retained top 80% of features based on importance.
# Selected 4 important features out of 6. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_4', 'Feature_6', 'Feature_1', 'Feature_2']
# Class imbalance handled: {0: np.int64(62), 1: np.int64(62)}
# Final dataset shape: (124, 4)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (80, 4)
# Dataset Dataset_42 Preprocessed Validation AUC: 0.9310
# Using raw data for Dataset Dataset_42.
# Dataset Dataset_43 Raw Validation AUC: 0.6947
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (593, 3)
# Selected 3 important features out of 3. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_3', 'Feature_1', 'Feature_2']
# Class imbalance handled: {1: np.int64(506), 0: np.int64(506)}
# Final dataset shape: (1012, 3)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (396, 3)
# Dataset Dataset_43 Preprocessed Validation AUC: 0.8808
# Using preprocessed data for Dataset Dataset_43.
# Dataset Dataset_44 Raw Validation AUC: 0.9922
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (60, 4)
# Retained top 80% of features based on importance.
# Selected 3 important features out of 4. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_1', 'Feature_3', 'Feature_2']
# Class imbalance handled: {1: np.int64(43), 0: np.int64(43)}
# Final dataset shape: (86, 3)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (40, 3)
# Dataset Dataset_44 Preprocessed Validation AUC: 1.0000
# Using preprocessed data for Dataset Dataset_44.
# Dataset Dataset_45 Raw Validation AUC: 1.0000
# Dataset Dataset_45 reached perfect AUC without preprocessing. Skipping preprocessing.
# Dataset Dataset_46 Raw Validation AUC: 0.8665
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (176, 8)
# Selected 8 important features out of 8. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_9', 'Feature_7', 'Feature_13', 'Feature_6', 'Feature_8', 'Feature_1', 'Feature_2', 'Feature_3']
# Class imbalance handled: {0.0: np.int64(107), 1.0: np.int64(107)}
# Final dataset shape: (214, 8)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (118, 8)
# Dataset Dataset_46 Preprocessed Validation AUC: 0.8295
# Using raw data for Dataset Dataset_46.
# Dataset Dataset_47 Raw Validation AUC: 0.8760
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (86, 75)
# Retained top 80% of features based on importance.
# Selected 60 important features out of 75. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_49', 'Feature_31', 'Feature_21', 'Feature_57', 'Feature_3', 'Feature_51', 'Feature_70', 'Feature_1', 'Feature_6', 'Feature_44', 'Feature_71', 'Feature_64', 'Feature_40', 'Feature_30', 'Feature_74', 'Feature_5', 'Feature_52', 'Feature_48', 'Feature_56', 'Feature_66', 'Feature_27', 'Feature_10', 'Feature_46', 'Feature_4', 'Feature_20', 'Feature_50', 'Feature_55', 'Feature_22', 'Feature_9', 'Feature_47', 'Feature_73', 'Feature_67', 'Feature_12', 'Feature_36', 'Feature_8', 'Feature_25', 'Feature_43', 'Feature_7', 'Feature_35', 'Feature_26', 'Feature_13', 'Feature_38', 'Feature_59', 'Feature_63', 'Feature_28', 'Feature_69', 'Feature_65', 'Feature_15', 'Feature_33', 'Feature_54', 'Feature_17', 'Feature_37', 'Feature_32', 'Feature_14', 'Feature_42', 'Feature_61', 'Feature_19', 'Feature_11', 'Feature_60', 'Feature_2']
# Class imbalance handled: {0: np.int64(59), 1: np.int64(59)}
# Final dataset shape: (118, 60)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (58, 60)
# Dataset Dataset_47 Preprocessed Validation AUC: 0.9446
# Using preprocessed data for Dataset Dataset_47.
# Dataset Dataset_48 Raw Validation AUC: 1.0000
# Dataset Dataset_48 reached perfect AUC without preprocessing. Skipping preprocessing.
# Dataset Dataset_49 Raw Validation AUC: 0.9806
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (575, 38)
# Retained top 80% of features based on importance.
# Selected 30 important features out of 38. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_21', 'Feature_3', 'Feature_41', 'Feature_6', 'Feature_1', 'Feature_5', 'Feature_27', 'Feature_10', 'Feature_20', 'Feature_22', 'Feature_34', 'Feature_12', 'Feature_36', 'Feature_8', 'Feature_25', 'Feature_35', 'Feature_7', 'Feature_26', 'Feature_16', 'Feature_28', 'Feature_39', 'Feature_14', 'Feature_15', 'Feature_42', 'Feature_17', 'Feature_37', 'Feature_32', 'Feature_19', 'Feature_11', 'Feature_2']
# Class imbalance handled: {0: np.int64(368), 1: np.int64(368)}
# Final dataset shape: (736, 30)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (384, 30)
# Dataset Dataset_49 Preprocessed Validation AUC: 0.9893
# Using preprocessed data for Dataset Dataset_49.
# Dataset Dataset_5 Raw Validation AUC: 0.9621
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (324, 19)
# Selected 19 important features out of 19. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_3', 'Feature_2', 'Feature_5', 'Feature_19', 'Feature_11', 'Feature_6', 'Feature_13', 'Feature_14', 'Feature_7', 'Feature_9', 'Feature_17', 'Feature_1', 'Feature_16', 'Feature_12', 'Feature_15', 'Feature_18', 'Feature_8', 'Feature_4', 'Feature_10']
# Class imbalance handled: {0: np.int64(303), 1: np.int64(303)}
# Final dataset shape: (606, 19)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (216, 19)
# Dataset Dataset_5 Preprocessed Validation AUC: 0.9913
# Using preprocessed data for Dataset Dataset_5.
# Dataset Dataset_6 Raw Validation AUC: 0.9953
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (312, 14)
# Selected 14 important features out of 14. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_4', 'Feature_3', 'Feature_15', 'Feature_12', 'Feature_2', 'Feature_6', 'Feature_10', 'Feature_11', 'Feature_5', 'Feature_1', 'Feature_14', 'Feature_13', 'Feature_9', 'Feature_7']
# Class imbalance handled: {1: np.int64(188), 0: np.int64(188)}
# Final dataset shape: (376, 14)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (208, 14)
# Dataset Dataset_6 Preprocessed Validation AUC: 0.9891
# Using raw data for Dataset Dataset_6.
# Dataset Dataset_7 Raw Validation AUC: 0.9852
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (369, 12)
# Selected 12 important features out of 12. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_5', 'Feature_4', 'Feature_3', 'Feature_10', 'Feature_8', 'Feature_6', 'Feature_2', 'Feature_9', 'Feature_7', 'Feature_11', 'Feature_12', 'Feature_1']
# Class imbalance handled: {1: np.int64(321), 0: np.int64(321)}
# Final dataset shape: (642, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (246, 12)
# Dataset Dataset_7 Preprocessed Validation AUC: 0.9986
# Using preprocessed data for Dataset Dataset_7.
# Dataset Dataset_8 Raw Validation AUC: 0.8073
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (179, 12)
# Selected 12 important features out of 12. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_7', 'Feature_5', 'Feature_12', 'Feature_6', 'Feature_3', 'Feature_11', 'Feature_2', 'Feature_4', 'Feature_1', 'Feature_8', 'Feature_9', 'Feature_10']
# Class imbalance handled: {0: np.int64(121), 1: np.int64(121)}
# Final dataset shape: (242, 12)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (120, 12)
# Dataset Dataset_8 Preprocessed Validation AUC: 0.9511
# Using preprocessed data for Dataset Dataset_8.
# Dataset Dataset_9 Raw Validation AUC: 0.9283
# Starting preprocessing pipeline...
# Training stage: Performing full preprocessing...
# Combined dataset shape: (144, 43)
# Selected 36 important features out of 43. (retained_top_fraction=0.8, importance_threshold=0.005)
# Selected features: ['Feature_32', 'Feature_13', 'Feature_43', 'Feature_19', 'Feature_29', 'Feature_26', 'Feature_14', 'Feature_10', 'Feature_44', 'Feature_40', 'Feature_22', 'Feature_21', 'Feature_31', 'Feature_33', 'Feature_11', 'Feature_24', 'Feature_6', 'Feature_25', 'Feature_42', 'Feature_45', 'Feature_23', 'Feature_17', 'Feature_37', 'Feature_20', 'Feature_27', 'Feature_28', 'Feature_18', 'Feature_39', 'Feature_8', 'Feature_36', 'Feature_15', 'Feature_46', 'Feature_34', 'Feature_16', 'Feature_5', 'Feature_30']
# Class imbalance handled: {1: np.int64(74), 0: np.int64(74)}
# Final dataset shape: (148, 36)
# Preprocessing pipeline completed.
# Starting preprocessing pipeline...
# Testing stage: Applying pre-selected features and encoder...
# Testing stage: Final dataset shape after applying selected features: (96, 36)
# Dataset Dataset_9 Preprocessed Validation AUC: 0.8689
# Using raw data for Dataset Dataset_9.
# Average AUC = 0.9369

# %% [markdown]
# >>> Plot Graph

# %%
import matplotlib.pyplot as plt
import numpy as np

# AUC_set values
AUC_set = [
    np.float64(0.8798),
    np.float64(0.9325),
    np.float64(0.9369),
]

classifiers = [
    "XGBoost (Raw)",
    "XGBoost (Preprocessed)",
    "XGBoost (Conditional Preprocessing)"
]

# Plotting the bar graph
plt.figure(figsize=(10, 5))
bars = plt.bar(classifiers, AUC_set, color='skyblue', alpha=0.8, label='Average ROC AUC Score')

# Annotate data points with their corresponding AUC values
for bar, value in zip(bars, AUC_set):
    plt.text(bar.get_x() + bar.get_width() / 2, value + 0.005, f"{value:.3f}", 
             ha='center', fontsize=10)  # Display AUC values above the bars

plt.title('ROC AUC Scores for XGBoost Classifier Variants', fontsize=14)  
plt.xlabel('Classifier Variants', fontsize=12)  
plt.ylabel('Average ROC AUC Score', fontsize=12)  
plt.ylim(0.7, 1.00)  # Set Y-axis limits
plt.grid(visible=True, linestyle='--', alpha=0.5, axis='y')  # Add horizontal gridlines
plt.legend(fontsize=10, loc='upper right')  # Add legend

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# AUC_set values
AUC_set = [
    np.float64(0.8798),
    np.float64(0.9325),
    np.float64(0.9369),
]

classifiers = [
    "XGBoost (Raw)",
    "XGBoost (Preprocessed)",
    "XGBoost (Conditional Preprocessing)"
]

# Define different colors for each bar
colors = ['skyblue', 'orange', 'lightgreen']

# Plotting the bar graph
plt.figure(figsize=(10, 4))
bars = plt.bar(classifiers, AUC_set, color=colors, alpha=0.8)

# Annotate data points with their corresponding AUC values
for bar, value in zip(bars, AUC_set):
    plt.text(bar.get_x() + bar.get_width() / 2, value + 0.005, f"{value:.3f}",
             ha='center', fontsize=10)  # Display AUC values above the bars

# Add a custom legend
plt.legend(bars, classifiers, fontsize=10, loc='upper left')

plt.title('ROC AUC Scores for XGBoost Classifier Variants', fontsize=14)
plt.xlabel('Classifier Variants', fontsize=12)
plt.ylabel('Average ROC AUC Score', fontsize=12)
plt.ylim(0.7, 1.00)  # Set Y-axis limits
plt.grid(visible=True, linestyle='--', alpha=0.5, axis='y')  # Add horizontal gridlines

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()
